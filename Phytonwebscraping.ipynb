# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import xlsxwriter

page_number = 1;
finish_page = 50;
comment_number = 0
dataset = list()

while page_number <= finish_page:
    books_url = "https://www.idefix.com/kategori/Kitap/Edebiyat/grupno=00055?ShowNotForSale=True&Page="+ str(page_number) + ""
    books_request = requests.get(books_url)
    books_html = BeautifulSoup(books_request.content,"lxml")

    books_div1 = books_html.find("div",attrs={"class":"no-margin productListNewBox boxes books clearfix"})
    books_div2 = books_div1.find("div",attrs={"class":"row"})
    books_list = books_div2.find_all("div",attrs={"class":"cart-product-box-view"})

    for book_html in books_list:
        book_link = "https://www.idefix.com/"+book_html.a.get("href")
        books_request = requests.get(book_link)

        book_page_html = BeautifulSoup(books_request.content,"lxml")
        comments_html = book_page_html.find_all("div",attrs={"class":"comment"})

        book_div1 = book_page_html.find("div",attrs={"class":"product-info hidden-lg hidden-md hidden-sm col-xs-12"})
        if(book_div1 is None):
            print("hata tespit")
            continue
        book_name = book_div1.find("h3",attrs={"style":"margin-bottom: 10px !important; margin-top: 0px;"}).get_text().replace('\n',"").replace(' ',"")
        print(str(page_number)+book_name)
        
        if (len(comments_html) != 0):
            for comment_html in comments_html:
                comment = comment_html.find(id="reviewBody").get_text()
                data = [book_name, comment]
                dataset.append(data)
                comment_number += 1
    page_number += 1
print("Comment number: "+ str(comment_number))
# Out:
# 1Siddhartha
# 1BilimÇocuk-Mayıs2022
# 1ÇavdarTarlasındaÇocuklar
# 1NietzscheAğladığında
# 1AynalıTılsımlarDükkanı
# 1Swann'larınTarafı-KayıpZamanınİzinde1.Kitap
# 1Koku
# 1SıfırNoktasındakiKadın
# 1Açlık
# 1GüvenlikDuvarı-KurtWallanderSerisi8
# 1Koleksiyoncu
# 1PusluKıtalarAtlası
# 1MetinAkpınar:SahneyeAdanmışBirÖmür
# 1TatarÇölü
# 1DokuzuncuHariciyeKoğuşu
# 1AşkveÖbürCinler
# 1Venedik'teÖlüm
# 1SaçÖrgüsü
# 1SözUçarHasarKalır
# 1Bavul
# 1AşıkErkeklerGizliGörevde
# 1Mülksüzler
# 1KadınınAdıYok
# 1BirBilimAdamınınRomanı
# 1YediYıl
# 1Körleşme
# 1YakutOrman
# 1Sevilen
# 1NeYaptığınıBiliyorum
# 1Ahmakıslatan
# 1HarryPotterveFelsefeTaşı-1.Kitap
# 1KuyucaklıYusuf
# 1BirDinozorunAnıları
# 1İmzalı-SöylenmemişSözler
# 1Suskunlar
# 1GizliAkşamYemeği
# 2Zorba
# 2ÇiçekAçmışGençKızlarınGölgesinde-KayıpZamanınİzinde(ikincikitap)
# 2GelEveDönelim
# 2İçimizdekiŞeytan
# 2DemBuDemdirSaatBuSaat-GönülSadası'ndanAkisler-4
# 2YetişkinlerveİleriDüzeydeÖğrencilerİçinDansDersleri
# 2İçimizdekiŞeytan-TürkEdebiyatKlasikleri31
# 2BitmeyenKavga
# 2ZaferTakı-ModernKlasikler
# 2FB2019-20SezonTaraftarKartlarıTekliPaket-Ağustos2020
# 2SkandallarKraliçesi
# 2KarısınıŞapkaSananAdam
# 2MetroKutuluSet3KitapTakım
# 2Tutunamayanlar-BütünEserleri-1
# 2AğaçlarınÖzelHayatı
# 2GülünAdı
# 2Başkaldıranİnsan
# 2TanteRosa
# 2Tavanarası
# 2AyaşlıileKiracıları
# 2CehennemeÖvgü
# 2AfrikalıLeo
# 2ÇalışmanınMutluluğuveSıkıntısı
# 2SaatleriAyarlamaEnstitüsü
# 2Yaban
# 2KaranlığınSolEli
# 2BirÇiftYürek
# 2YaşamınUcunaYolculuk
# 2Onay-DavaÖzetleri2
# 2ZamanınFarkında
# 2Sofie'ninDünyası
# 2OperadaCinayet-BirVenedikPolisiyesi1
# 2Kambur
# 2SuyuArayanAdam
# 2KaranlıkKız
# 2ZayıfBedenlereYüktürAşk
# 3Buffett-BirAmerikanKapitalistininYükselişi
# 3Paçinko
# 3Faust-Asya-HasanAliYücelKlasikler
# 3Düşüş
# 3Doğu'nunLimanları
# 3YıldırımSesliManasçı
# 3DalgalarBeniÇağırır-ErdenEruç
# 3EnkazAltındakiler
# 3YaşamadanÖlmeyeceğim
# 3KafaDergisi-Mayıs2022
# 3BüyülüDağ-2CiltTakım
# 3Suçlusunuz
# 3BüyükUyku
# 3UyurgezerlerÜçlemesiSeti-3KitapTakım-Kutulu
# 3İmzalı-Taksiii
# 3OğullarveRencideRuhlar
# 3Mandarinler
# 3HayBinYakzan
# 3Aynalar
# 3KarantinaDördüncüPerde-MahşerinDörtAtlısınınHikayesi
# 3BaşkaZamanKütüphaneleri
# 3AklımınAynalıÇarşısı
# 3KorkuyuBeklerken-BütünEserleri4
# 3KorkuÇağındaÇocukYetiştirmek
# 3UzunSürmüşBirGününAkşamı
# 3BaharKarları
# 3HarryPotterveSırlarOdası-2.kitap
# 3FrannyveZooey
# 3BinMuhteşemGüneş
# 3TatlıPerşembe
# 3PolisiyeYazarınınÖlümü
# 3KışınHerkesDürüsttür
# 3AşıkErkeklerKitapKulübü
# 3BrutusileMektuplaşmalar-HasanAliYücelKlasikler
# 3SanaGülBahçesiVadetmedim
# 3Enstantaneler
# 4Ev
# 4MorBirSerserininGeziNotları
# 4Şafak-SevgiSoysalBütünEserleri
# 4Salambo
# 4ElleriTitremedenAteşiTutabilene
# 4CoşkuylaÖlmek
# 4ÇılgınPalmiyeler
# 4DümeniYaratıcılığaKırmak
# 4EveDönmeninYolları
# 4AsılacakKadın
# 4DerdeDevaRandevu-3
# 4Kimsesiz
# 4Veba
# 4Kitab-ülHiyel
# 4İşitmeMesafesindeÖtekiDil-ŞiirÇevirisiHakkındaİnceleme
# 4YukarıMahalle
# 4BabylonBerlin-IslakBalık
# 4Verity:GerçeğinDiğerKıyısı
# 4ÖlümcülKimlikler
# 4RuhlarEvi
# 4KanatsızKuşlar
# 4IssızlığınOrtası
# 4BenimOlağanüstüAkıllıArkadaşım
# 4OGünİçinBirŞemsiye
# 4NasılYapmalı?
# 4Medyum
# 4BilimveTeknik-Mayıs2022
# 4DağlarınEzgisi
# 4AteşinVaadi
# 4NeİçinVarsanOnunİçinYaşa-BirArayışınRomanı
# 4BatanGüneş
# 4ErtelemeSanatı
# 4BeşŞehir
# 4BirSüreYereParalelGittiktenSonra
# 4ÖlümcülSırlar
# 4Yalnızız
# 5DenizKıyısındaKoşanAlaKöpek
# 5Yalnızız
# 5BitikAdam
# 5Divan
# 5DublörDilemması
# 5ÖlümCanDüşmanım
# 5Lizbon'aGeceTreni
# 5EvliyaÇelebiSeyahatnamesiSeti-2KitapTakım
# 5ÖlümdenBeterYazgılar
# 5AraplarveHikayeAnlatmaSanatı-TuhafBirAşinalık
# 5ErkeğinYittiğiYerde
# 5EnUzakSahil-YerdenizÜçlemesi3
# 5ParasızYatılı-Füruzan
# 5BizimKöy
# 5Fatih'tenBeyoğlu'naBenimİstanbul'um
# 5CahillerleTartışmayaGirmeyinBenHiçYenemedim
# 5Kasiyer
# 5KahveSoğumadanÖnce
# 5NiteliksizAdamSeti-4KitapTakımKutulu
# 5AvuçlarımdaHalaSıcaklığınVar
# 5BirDinozorunGezileri
# 5LewisHamilton:TümZamanlarınEnBüyükYarışPilotununYaşamÖyküsü
# 5ManşettekiCinayet-BirOsmanAysuPolisiyeRomanı
# 5HerUmutOrtakArar
# 5Aptal
# 5İzdivaç
# 5MartıJonathanLivingston
# 5Ulysses
# 5FransızTeğmeninKadını
# 5DillerinKökeniÜstüneDeneme-HasanAliYücelKlasikleri
# 5KorkuEvi-YedinciAt-BütünÖyküleri
# 5KediMektupları
# 5AnadoluEfsaneleri
# 5GerçekOlamayacakKadarGüzel
# 5TürkçeDublajlıİtalyanFilmleriGibiyiz
# 5Kalıntı-2
# 6CengizHan'aKüsenBulut
# 6T.Singer
# 6AnadoluTanrıları
# 6Lena'nınKüçükYolculuğu
# 6AşkaÖvgü
# 6İstanbul'unKayıpMührü
# 6KadimzamanlarveDiğerVakitler
# 6Sihirbaz-BirThomasMannBiyografisi
# 6İnsanlığımıKaybedişim
# 6RuhiMücerret
# 6IhlamurlarAçarken
# 6Rakipler
# 6Fable
# 6GidenGitmişHüznüAyaklandırmakBoşuna
# 6EdebiyatKuramı
# 6TehlikeliOyunlar
# 6AtuanMezarları-YerdenizÜçlemesi2
# 6KüçükŞeylerinTanrısı
# 6SisifosSöyleni
# 6AdsızRoman1864-ÇerkesSürgünüveSoykırımı
# 6BabamınCinayetDefteri
# 6YalancılarveYabancılar-2
# 6Hernani-CemilMeriçBütünÇevirileri
# 6NergisHanımHakkındaBazıŞeyler
# 6HızlandıkçaAzalıyorum
# 6AteşSöneneKadar
# 6BizimleBaşladıBizimleBitti
# 6SilinmişSahneler
# 6FesiDüşürmeden-PakratEstukyanAnlatısı
# 6MariaSuphi:BirDirenişÖyküsü
# 6TeslaSetiKutulu-3KitapTakım
# 6Duvar
# 6Hadula-BirAdaÖyküsü
# 6EldenDüşmeDünya
# 6TarihiKırıntılar
# 6Dokunmadan
# 7RüyalarAnlatılmaz
# 7SessizliğinDünyası
# 7BütünİyilerBirazKüskündür
# 7FırtınaışığıArşiviDördüncüRoman-SavaşRitmi1.Cilt
# 7Yükseliş
# 7OlduğuKadar-ÜçGünlükDünyaEdebiy
# 7Efrasiyab'ınHikayeleri
# 7ToprakUyanırsaEkmeksizköyÖğretmenininHatıraları
# 7SonBakıştaAşk
# 7Utanç
# 7VecizSözler
# 7Baba
# 7KaranlıkSır
# 7ÖlülerKonuşamaz
# 7MeraklıMinik-Mayıs2022
# 7Lukov'danSevgiler
# 7EskiBahçeEskiSevgi
# 7Kalanlar
# 7YerdenizBüyücüsü-YerdenizÜçlemesi1
# 7LabirentindekiGeneral
# 7TutkuluPerçem
# 7Hırsız
# 7ÇernobilDuası-GeleceğinTarihi
# 7Tenveİz
# 7ÖyleMiymiş?
# 7ÇalışanınFizyolojisi
# 7KorkmaBenVarım
# 7TristramShandyBeyefendi'ninHayatı
# 7AyveŞenlikAteşleri
# 7KoleraGünlerindeAşk
# 7ZenveMotosikletBakımSanatı-DeğerlerinSorgulanması
# 7DokuzÖykü
# 7KlasikOkumaları2-TutunamayanlarÇağı
# 7CharlieChaplin
# 7Çiftlik
# 7KınalıÇiçekler
# 8İkinciHayatınTekBirHayatınOlduğunuAnladığındaBaşlar
# 8ModernÖykü-TeorikvePratikBirÇalışma
# 8KumralAdaMaviTuna
# 8KelebeğiÖldürmek-1
# 8HerkesHerkesleDostmuşGibi
# 8KendiniKeşfet-BireyleşmeninAlbenisiÜzerine
# 8Karsambaç
# 8Budala
# 8TütünYorgunu
# 8BuradaAyrılıyoruz
# 8DarKapı
# 8Duyuyormusun?
# 8DevrimdenÖncekiGün
# 8Yürümek/SevgiSoysalBütünEserleri
# 8MükerremHanım'ınKuşkonmazMasası
# 8Kul
# 8Üçİstanbul-BüyükBoy
# 8GöçmüşKedilerBahçesi
# 8HacıAga
# 8GülününSolduğuAkşam
# 8AgantaBurınaBurınata
# 8BinbirGeceMasalları4/1
# 8TerkEdenlerveKalanlar
# 8KendiHayatındaÖlmeVakti
# 8Victoria
# 8KışYazaKavuşunca
# 8TozaSor
# 8Hadrianus'unAnıları
# 8BereketliTopraklarÜzerinde
# 8İkiKişilikYalnızlık
# 8Angela'nınKülleri-Hatıralar
# 8NazımHikmetle3.5Yıl
# 8EzilmişVeAşağılanmışlar
# 8TürkMilliKültürü
# 8Vejetaryen
# 8HerKalpKırılır
# 9Yaralasar2
# 9İmzalı-DışGüzellikYasaklansınRuhGüzelliğineGeçelim
# 9YazmaSanatı
# 9ÖlümAllah'ınEmri-TürkEdebiyatKlasikleri60
# 9VişneninCinsiyeti
# 9Kitap-lıkDergisiSayı221
# 9HırsızlarınDansı
# 9KanınıSatanAdam
# 9GeceninGözleri
# 9YalnızKadınlarArasında
# 9GoriotBaba
# 9AnkaraMonAmour!
# 9RomantikHareketSeksAlışverişveRoman
# 9GözünÖyküsü
# 9OtoyolUykusu
# 9OkumakYazmakveDüşünmekÜzerine
# 9SuBaşındaDurmuşuz
# 9NationalGeographic(Tr)-Mayıs2022
# 9CinayetUstası
# 9SardalyeSokağı
# 9KiralıkKonak
# 9GülümseyenAdam-KurtWallanderSerisi4
# 9The100SerisiSeti-4KitapTakım
# 9YaşamaUğraşı-Günlükler1935-1950
# 9MaviSürgün
# 9BaşkanBabamızınSonbaharı
# 9GençBirŞaireMektuplar
# 9MahirÇayanve68DevrimciKuşağı
# 9KayıpKızınHikayesi
# 9Derin
# 9BaşıboşKöpek-CommissarioMorelloVenedik'te
# 9HayvanÇiftliğiveOkumaRehberi
# 9TespihTaneleri
# 9MisterPickwick'inSerüvenleri
# 9FikriminİnceGülü
# 9Sultanmurat
# 10BüyükPortreBüyükSır
# 10İlahiKomedyaSeti-3KitapTakımÖzelKutulu
# 10Hamido
# 10SessizlikOteli
# 10YıldızlaraGülümseyenKız
# 10ŞahAbbas:İranıYenidenŞekillendirenHükümdar
# 10VerandaÖyküleri
# 10KırmızıZambak
# 10Tehanu-YerdenizÜçlemesi4
# 10BirGünlükYerimKaldıİstermisiniz?
# 10OnİkiGeziciÖykü
# 10GüzSancısı
# 10HerGeceBodrum
# 10Okuyucu
# 10DüşünceDüşlenir
# 10NezleliKarga
# 10Dublinliler
# 10CamŞato
# 10Adolphe
# 10OnİkiSandalye
# 10KatmerliSahtekar-BirSoluktaKlasikler
# 10HerNeArarİsenKendindeAra
# 1021.YüzyılTürkŞiiriŞairlerAkımlarSorunlar
# 10SaklıBahçelerHaritası
# 10TüneldenÖncekiBeyazEv
# 10YanlışHayatDoğruYaşanmaz
# 10KaçakAtlar
# 10YüzüncüAd-Baldassare'ninYolculuğu
# 10NiteliksizAdam1
# 10Fatih-Harbiye
# 10DonQuijote(2CiltTakım)
# 10Starsight-Skyward2
# 10CevapsızMektuplar
# 10Saint-Germain-des-PresRehberi
# 10BabaBizeNedenDönmeDiyorlar?
# 10HayatınTümRenkleri
# 11DünyaAtı
# 11YeryüzündeBirAnİçinMuhteşemiz
# 11YüksekŞatodakiAdam
# 11Misafir
# 11AcıyaKurşunİşlemez
# 11DervişveÖlüm
# 11Büyüyemeyenler
# 11Heidi-BezCiltli
# 11Lolita
# 11Koşucular
# 11Mussolini:Otobiyografim
# 11Labirent
# 11Flanöz:ŞehirdeYürüyenKadınlar
# 11KöprüKrallığı
# 11Divan-ıTürkiBasit'inGramerveLügatçesi
# 11SalaminaAskerleri
# 11YabancıKadın
# 11BenBirKediyim
# 11SonBakış
# 11PeygamberdenSonra
# 11AzrailKoşuyor
# 11Anomali
# 11EntelektüelinKutsalKitabı-Biyografiler
# 11HerkesHerŞeyinFarkında
# 11Seyir
# hata tespit
# 11HerYerdenÇokUzakta
# 11Günlük
# 11Saklambaç
# 11GeçKalmışÖlü
# 11GaripTicaretlerKulübü
# 11Taaşşuk-ıTalatveFitnat-GünümüzTürkçesiyle
# 11HerGünHüzün-Solayağım2
# 11KendineAitBirOda
# 11SardalyeSokağı
# 11KalbiminCanMayası
# 12SalaminaAskerleri
# 12KaybolmaKılavuzu
# 12BilgeKarasu:DirimBelirtileri:Işık,Zemin,Hayvan-AnlatıDesenleri3
# 12SardalyeSokağı
# 12ÇiçeklerinZekası
# 12İtiraz
# 12Tiraje
# 12KirliydiKar
# 12SağırCumhuriyet
# 12BudalalığınKeşfi
# 12Çürüme
# 12Öbürküler
# 12BeşirAğa:OsmanlıHaremininBaşHadımAğası
# 12PilotOlmak-BirSavaşPilotununAnıları
# 12ŞeytaniBoyut
# 12PulpanınIşığında
# 12Lyon'daDüğün
# 12BüyükVuruş
# 12UnutulmazKöyEnstitüleri
# 12Asal
# 12KalbiminCanMayası
# 12Ubik-PKD
# 12Aspern'inMektupları
# 12AtlıkarıncadaBirTurDaha
# 12SokakNöbetçileri
# 12OğuzAtay:YazıEylemiveOyun-AnlatıDesenleri1
# 12DiriGömülen
# 12BuKitabıÇalın
# 12YüzüklerinEfendisi-III-KralınDönüşü
# 12Romantika
# 12Kalpazanlar
# 12BaştanÇıkarıcınınGünlüğü
# 12Delifişek
# 12YüreğininGötürdüğüYereGit
# 12Huzur
# 12HiçbirZamanBuradaDeğildin
# 13BaştanÇıkarıcınınGünlüğü
# 13YüzüklerinEfendisi-III-KralınDönüşü
# 13Delifişek
# 13YüreğininGötürdüğüYereGit
# 13Kalpazanlar
# 13BuKitabıÇalın
# hata tespit
# 13FrankfurtYolcusu
# 13PafvePuf
# 13ÖlümOyunu
# 13PeriGazozu
# 13TefrikaİkiBinOnBeş
# 13Masumlar
# 13Münih'eKadar6Mezar
# 13BirKediBirAdamİkiKadın
# 13PrensesBari
# 13TanrıOlmakİsteyenOtobüsŞöförü
# 13BeyazZambaklarÜlkesinde-BezCiltli
# 13İlahiKomedya-CehennemArafCennet(3CiltTakım)
# 13BuSu
# 13BoyalıKuş
# 13KoşMeloş!
# 13TrenleSeyahatinAvantajları
# 13O
# 13SonsuzluğunSonu
# 13BirDüğünGecesi-DarZamanlar2
# 13Yolda
# 13Nil'deÖlüm
# 13YeşilDenizKabuğu
# 13Sınırsız
# 13LeMondeDiplomatiqueTürkçe-Nisan2022
# 13OperatöreBağlanıyorsunuz-1
# 13BirKatilinGüncesi
# 13YanlışlıklarKomedyası-HasanAliYü
# 13DonKişotİlkesi
# 13UzunYolculuğum-BirYanımızHepÇocukKaldı
# 14KoşMeloş!
# 14BoyalıKuş
# 14İlahiKomedya-CehennemArafCennet(3CiltTakım)
# 14BirKediBirAdamİkiKadın
# 14PrensesBari
# 14ÇıplakCeset-ÖzelBaskı
# 14BirDilekYetmez
# 14TanrıOlmakİsteyenOtobüsŞöförü
# 14O
# 14BeyazZambaklarÜlkesinde-BezCiltli
# 14Gece
# 14AlbayaMektupYok
# 14FoucaultSarkacı
# 14MutluÖlüm
# 14KucaklaşmanınKitabı
# 14DünyayaOrmanDenir
# 14Mrs.Dalloway
# 14LatinAmerika'nınKesikDamarları
# 14SalkımSalkımAsılacakAdamlar
# 14AnneminKaburgası
# 14KarıncalarınGünbatımı
# 14SonKız:EsaretiminHikayesiveIŞİD'leMücadelem
# 14Balıkçılar
# 14Cogito93-YerküreKriziDönüşenİnsan
# 14Geliş
# 14ÇelikFırtınalarında
# 14ParisDüşerken
# 14SesSeseKarşı
# 14Amak-ıHayal
# 14Irazca'nınDirliği
# 14Carl'ınKitabı-ÖlümSendenBirşeyAldığındaOnuGeriVer
# 14AliceTeşkilatı
# 14VatanımYugoslavya
# 14CahitKayraAnısına
# 14BinGemi
# 14NazlıEray:ÖmürUzatmaKahvehanesi-EverestAçıkhava15
# 15Muaz
# 15YitikBirAşkınGölgesinde
# 15KaranlığınKalbi
# 15NazlıEray:ÖmürUzatmaKahvehanesi-EverestAçıkhava15
# 15Faust-Asya-HasanAliYücelKlasikler
# 15KarıncalarınGünbatımı
# 15OnuncuKöy
# 15Soğukkanlılıkla
# 15İnsanNedir?
# 15Carl'ınKitabı-ÖlümSendenBirşeyAldığındaOnuGeriVer
# 15BirÖnYargıMeselesi-ÇağdaşKlasikler
# 15CahitKayraAnısına
# 15BinGemi
# 15AliceTeşkilatı
# 15VatanımYugoslavya
# 15CharlieChaplin-AşağıBakarsanızAslaGökkuşağıBulamazsınız
# 15BurasıRadyoŞarampol
# 15RızasıVar
# 15BirAdımGeriden-KurtWallanderSerisi7
# 15FelsefiDüşünSayı18-Nietzsche
# 15HikayeAnlatmaSanatı
# 15DavetliListesi
# 15AzraKohenSeti-3KitapTakımKutulu
# 15LüzumsuzAdam-ModernTürkEdebiyatıKlasikleri12
# 15BinbirGeceMasalları3/1
# 15BinbirGeceMasalları3/2
# 15Ağ
# 15YüzüklerinEfendisi-I-YüzükKardeşliği
# 15Ateşler
# 15EdebiyatKuramlarıveEleştiri
# 15UçurtmayıVurmasınlar
# 15Bonzai
# 15TahtOyunları
# 15Tenkit
# 15Terkediş
# 15DöngelDünya
# 16MeyhaneİhtisasKitabı-BüyükBoy
# 16Tarantula
# 16Swann'larınTarafı
# 16RunGülüzarRun
# 16ModernDünyaKlasikleriSeti-7KitapTakım
# 16BirPsikiyatristinAnıları
# 16DanBrown-Set-RobertLangdonSerisi-5KitapTakım
# 16HerYasOnSekizAySürer
# 16Leş-BezCiltli
# 16Arabulucu
# 16BahçeKüller
# 16MekanFeşmekan
# 16PinkFloyd-KilidiAçamazsanKırKapıyı
# 16İvanOsokin'inTuhafHayatı
# 16Freud-MutluluğunMimarı
# 16HesabımVar
# 16YetişkinlerinYalanHayatı
# 16SiyahDivan-TopluŞiirler1998-2013
# 16Sınır
# 16MutluluğunParfümüYağmurAltındaDahaGüzelKokar
# 16KöprüKrallığı
# 16Armine
# 16Rağmen4:İstanbulaSöz
# 16İlahiKomedya-Cennet
# 16BirHayatÜçDönem:Anılar-Tanıklıklar
# 16FarseerÜçlemesi-3KitapTakımKutulu
# 16ŞemsTebrizi-AşkınGözyaşları1
# 16YoldaBirKuşaRastladım
# 16365GünDaha-365Gün-3.Kitap
# 16SokakNöbetçileri2
# 16FırtınaışığıArşiviDördüncüRoman-SavaşRitmi2.Cilt
# 16KarıncaYuvasınıDağıtmamak
# 16RaşomonveDiğerÖyküler
# 16SarıOdanınEsrarı-ModernKlasikler156
# 16EdgarAllanPoeSeti-4KitapTakım
# 16HenryJames:HalıdakiMotif-EverestAçıkhava16
# 17Kappa
# 17PoenunKuzgunu
# 17EvÖdevi
# 17YazGeçer
# 17KahramanlarHepErkek
# 17AltıncıKıta-Akdeniz
# 17DünyaNimetleriveYeniNimetler
# 17ÖncekiGününAdası
# 17BinbirGeceMasalları4/2
# 17BeyazZambaklarÜlkesinde
# 17Münevver
# 17Çocukluğum
# 17ZorakiDiplomat
# 17AcıKahve
# 17EvlerdenBiri
# 17SevmekZorundaDeğilsinBeni
# 17SonSefarad
# 17SinemaveFelsefe
# 17VeGünlerYürümeyeBaşladı
# 17SuçveCeza
# 17YatakOdasındaFelsefe
# 17İkinciElZaman-KızılİnsanınSonu
# 17SonHediye
# 17Sis-TamMetin
# 17AnılarlaBalıkçı'yaMerhaba
# 17EvreninYapısı
# 17TuhafGünlerPeşimizde
# 17ŞahikaFeraye
# 17Kün
# 17KayıpYaz2015
# 17MadrabazKvaçi
# 17KadınYokSavaşınYüzünde
# 17KutadguBilig-Kutulu3KitapTakım
# 17Pir-iLezzet
# 17TrenlerÇıldırırsa
# 17JulıaileAkşamYemeği
# 18ÜçKöşeliDünya
# 18AdıÖküzdenSonraGelen
# 18ÇekipGideneHerŞeyMizahKalıpBekleyeneHerŞeyŞiirdir
# 18DüşüncelerinKanatlarıVardır-KimseOnlarınİnsanlaraUlaşmasınaEngelOlamaz
# 18YaşadınızÖldünüzBirAnlamıOlmalıBunun
# 18Kapalıçarşı
# 18GöremediğimizTümIşıklar
# 18TomSawyer'ınMaceraları
# 18BedenineYazılıMasallar
# 18Tünel
# 18UyuyanAdam
# 18AkılÇağı-ÖzgürlükYolları1.Kitap
# 18AşktanveGölgeden
# 18SeniİçimeGömdüm
# 18PiedraIrmağınınKıyısındaOturdumAğladım
# 18Yaralısın
# 18KalecininPenaltıAnındakiEndişesi
# 18Murphy
# 18BeyazZenciler
# 18SalkımHanım'ınTaneleri
# 18BinbirGeceMasalları1/2
# 18BağışlanmanınDörtYolu
# 18Stiller
# 18BirAşkSöylemindenParçalar
# 18EkmekArası
# 18SenDeGitmeTriyandafilis
# 18Meyyale
# 18NeKitapsızNeKedisiz
# 18ÖlümüOynamak
# 18BeyazZambaklarÜlkesinde
# 18ÖzdeBilim
# 18AyşeKulin:DoğdumKızdım-EverestAçıkhava19
# 18AhmetTelli:GidersenYıkılırBuKent-EverestAçıkhava21
# 18Fable
# 18BirRomanKahramanıOrhanVeli
# 18ÜmitDünyası
# 19ÖncekiGününAdası
# 19BinbirGeceMasalları4/2
# 19Değirmen
# 19BeyazZambaklarÜlkesinde
# 19OtostopçununGalaksiRehberi
# 19ŞeytanınÇalgıları
# 19365GünDaha-365Gün-3.Kitap
# 19Münevver
# 19Çocukluğum
# 19ZorakiDiplomat
# 19AcıKahve
# 19EvlerdenBiri
# 19SevmekZorundaDeğilsinBeni
# 19SonSefarad
# 19SinemaveFelsefe
# 19VeGünlerYürümeyeBaşladı
# 19SuçveCeza
# 19YatakOdasındaFelsefe
# 19İkinciElZaman-KızılİnsanınSonu
# 19SonHediye
# 19Sis-TamMetin
# 19AnılarlaBalıkçı'yaMerhaba
# 19EvreninYapısı
# 19TuhafGünlerPeşimizde
# 19ŞahikaFeraye
# 19Kün
# 19KayıpYaz2015
# 19KadınYokSavaşınYüzünde
# 19KutadguBilig-Kutulu3KitapTakım
# 19Pir-iLezzet
# 19TrenlerÇıldırırsa
# 19JulıaileAkşamYemeği
# 19ÜçKöşeliDünya
# 19AdıÖküzdenSonraGelen
# 19ÇekipGideneHerŞeyMizahKalıpBekleyeneHerŞeyŞiirdir
# 19DüşüncelerinKanatlarıVardır-KimseOnlarınİnsanlaraUlaşmasınaEngelOlamaz
# 20YaşadınızÖldünüzBirAnlamıOlmalıBunun
# 20Kapalıçarşı
# 20GöremediğimizTümIşıklar
# 20TomSawyer'ınMaceraları
# 20BedenineYazılıMasallar
# 20Tünel
# 20UyuyanAdam
# 20AkılÇağı-ÖzgürlükYolları1.Kitap
# 20AşktanveGölgeden
# 20SeniİçimeGömdüm
# 20PiedraIrmağınınKıyısındaOturdumAğladım
# 20Yaralısın
# 20KalecininPenaltıAnındakiEndişesi
# 20Murphy
# 20BeyazZenciler
# 20SalkımHanım'ınTaneleri
# 20BinbirGeceMasalları1/2
# 20BağışlanmanınDörtYolu
# 20Stiller
# 20BirAşkSöylemindenParçalar
# 20EkmekArası
# 20SenDeGitmeTriyandafilis
# 20Meyyale
# 20NeKitapsızNeKedisiz
# 20ÖlümüOynamak
# 20BeyazZambaklarÜlkesinde
# 20ÖzdeBilim
# 20AyşeKulin:DoğdumKızdım-EverestAçıkhava19
# 20AhmetTelli:GidersenYıkılırBuKent-EverestAçıkhava21
# 20Fable
# 20BirRomanKahramanıOrhanVeli
# 20ÜmitDünyası
# 20BirŞansDaha?
# 20SonGemi-Akheron'unKapılarındanGeçiş
# 20KadereKarşıKoyA.Ş.
# 20ŞeytanTozu-ModernKlasiklerDizisi124
# 21ŞahitveAnlattıkları:Meşahidül-esrar
# 21KızılElma-OğullaBuluşma
# 21Yen
# 21Morg:ÖlümünİçindeYaşam
# 21SonTanıklar-ÇocukluğaAykırıYüzÖykü
# 21ŞairEvlenmesi-TürkEdebiyatıKlasikleri5
# 21ÇocukGeliyor
# 21ÖtanaziOkulu1
# 21BirSavaşVardı
# 21MevlananınKedisi
# 21AhmedAvniKonuk:GörünmeyenUmman
# 21Shantaram
# 211984
# 21EvreninSonundakiRestoran
# 21KırklarMeclisiHünkarBektaş
# 21DaVinciŞifresi
# 21Özgürlük
# 21OperatöreBağlanıyorsunuz-2
# 21Salgınİstanbul
# 21DarkPolisiye1.Kitap
# 21DoktorUyku
# 21KarantinaDördüncüPerde-MahşerinDörtAtlısınınHikayesi
# 21KesinDöneceksiniz
# 21BeşinciKadın-KurtWallanderSerisi6
# 21Eylembilim
# 21VarlıkDergisiSayı1376-Mayıs2022
# 21KöşedekiDükkan
# 21AzizlerveAlimler
# 21GozoveSagre
# 21IssızKarTaneleri
# 21Uyanış
# 21Dalgalar-DünyaKlasikleriSerisi
# 21ArsenLüpen-KibarHırsız
# 21KızlarveYıldızlar-ServerBediKülliyatı
# 21CamilleClaudel-BirKadın
# 21İlahiKomedya-Araf
# 22HikayenizOlmasaKimOlurdunuz?
# 22LeylaileMecnun
# 22SadıkRuslan
# 22LeylaErbil:BilinçAkışındaKesintiler-AnlatıDesenleri4
# 22OSokağaAslaGirme
# 22GüzelDost-HasanAliYücelKlasikleri
# 22BıçağınUcu
# 22ŞafakTapınağı
# 22İtalyanMasalları
# 22DervişKelamı
# 22HerKuyudaBirYusuf
# 22Juvenil
# 22Veli
# 22Sadi-HayatınAşkınveTutkununŞairi
# 22OkyanustakiRüzgar
# 22RüzgarKanatlıydılar-KöyEnstitüleriveTürkiye
# 22BütünŞiirleri
# 22AkşamüstüEzgisi
# 22SatanistCinler
# 22BertoltBrecht:CesaretAnaveÇocukları-EverestAçıkhava4
# 22JeanGiono:AğaçDikenAdam-EverestAçıkhava17
# 22AçıklamalıDivanŞiiriSözlüğü-EskiTürkEdebiyatındaMazmunlarveİzahı
# 22SenBanaYasak
# 22BirRuhMacerası
# 22AşıkKadınlar
# 22HeliosFelaketi
# 22Goebbels'inHatıraları
# 22KaranlıklarınHükümdarı
# 22Göz
# 22ÜzümünKardeşliği
# 22AutoShow-Nisan/Mayıs2022
# 22AhmetHamdiTanpınar-BütünŞiirleri
# 22BirMüftü'nünHatıraları
# 22MoliereEfendi
# 22DünyaLekesi
# 22ZatenHerkesTekBaşınaDeğilmi?
# 23SaydamŞeyler
# 23Halide
# 23Anayasso-YansımalarıylaBirlikteBirŞiir
# 23KrallarınÇarpışmasıKısım2
# 23EvSahibesi-HasanAliYücelKlasikleri
# 23İğrençAdamlarlaKısaGörüşmeler
# 23Gerçek
# 23ProustYaşamınızıNasılDeğiştirebilir?
# 23BahardaYineGeliriz
# 23DoğuÖyküleri
# 23PostacıKapıyıİkiKereÇalar
# 23CezaevindenMemetFuat'aMektuplar
# 23KayıpArkadaş
# 23KovadakiBalıklar
# 2301:01BugünAdımıSenKoy
# 23KlaraMiliç
# 23Gazali:İslamınDirilişi
# 23SürPulluğunuÖlülerinKemikleriÜzerinde
# 23Tokyo'nunSonÇocukları
# 23Yazsonu
# 23OkumakveYazmak
# 23BelkiBirGünUçarız
# 23YediKartalEfsanesi1.Kitap-ErbainFırtınası
# 23Dersim'inYazılamayanHazinHikayesi
# 23FinneganUyanması
# 23DelilimYokKalbimdenBaşka
# 23Har
# 23HayatımBuluşlarımveDüşüncelerim
# 23YavuzSultanSelim
# 23YeraltıDemiryolu
# 23JaponMasalları
# 23UluAğaç
# 23TarçınDükkanları
# 23ÖzümÇocuktur-ÖzyaşamÖyküsü1
# 23Ölümİlanı
# 23AdıAylin-MidiBoy
# 24GeceninKutsalKaranlığı
# 24Kundakçı-ÇinPolisiyesi1
# 24CanVerenPervaneler-2
# 24BanaSonunuSöyle
# 24Tamama-Pontus'unYitikKızı
# 24BeyazKitap
# 24YediKartalEfsanesi1.Kitap-ErbainFırtınası
# 24İsSerisiSeti-3KitapTakım
# 24Hayal
# 24Gündüzsefası
# 24PatetikSenfoni
# 24AdıAylin-MidiBoy
# 24JaponMasalları
# 24DoğalNedenler
# 24Uydurmanınİncelikleri:KurmacaÜzerineKişiselYaklaşımlar
# 24EdebiTekniklerve72YaratıcıYazarlıkDeneyi
# 24ÇocukluğumveÇocuğum
# 24İçindeBirSen2:Asreman
# 24GariplerinKitabı
# 24KarıncayıTanırsınız
# 24AnlatıyıYapıdanOkumak-ÇağdaşTürkRomanveHikayesininYapısalPanoraması
# 24Kapan
# 24Puglia'daBirÖmür
# 24HiçKimseninÇocuğu
# 24YeşilinKızıAnneRüya-BezCiltli
# 24Besteciler:YaşamlarıveEserleri
# 24UyanışMasalları
# hata tespit
# 24EdebiMekanınPoetikası
# 24MoliereEfendi
# 24DünyaLekesi
# 24SürPulluğunuÖlülerinKemikleriÜzerinde
# 24Tokyo'nunSonÇocukları
# 24Ölümİlanı
# 24Dersim'inYazılamayanHazinHikayesi
# 24KaranlıkOda
# 25SunaKıraç-ÖmrümdenUzunİdeallerimVar
# 25Katya'nınYazı
# 25TahirSamiBey'inÖzelHayatı
# 25Naomi:BirBudalanınAşkı
# 25AlgıKalesiRastlantıveDevinim
# 25İnsanınRuhunuYüceltenBirAcıUcuzBirMutluluktanDahaDeğerlidir
# 25Orion
# 25İçimdeKızılBirGülGibi
# 25KayıpRomanlar
# 25BuzdanAğabey
# 25SirteKıyısı
# 25Şifre
# 25ÖnceEkmek
# 25Uçurumİnsanları
# 25NefesiTutkuOlanKadın-AfifeJale
# 25Taksiii
# 25MeleklerveŞeytanlar
# 25KırmızıZaman
# 25Çağrı
# 25BirGünKedilerDünyadanYokOlsaydı
# 25ConanSeti-3KitapTakım
# 25KimsesizlerMatemi
# 25ÖlümcülOyun-DoğuştanYetenekliler
# 25Morel'inBuluşu
# 25BirTereddüdünRomanı
# 25Farahnaz'ınÇiçeği-BirYıldızAlatanMacerası
# 25Zehra-GünümüzTürkçesiyle-TürkEdebiyatıKlasikleri22
# 25Leylan
# 25Kya'nınŞarkıSöylediğiYer
# 25OynadımOynattımOynatalımErmanToroğluKitabı
# 25BenimAdımSena
# 25DeliKurt
# 25SonsuzSevgilerimle
# 25Palto
# 25MeraklıAdamınOnGünü
# 25Har
# 26UluAğaç
# 26ÖzümÇocuktur-ÖzyaşamÖyküsü1
# 26YeraltıDemiryolu
# 269.Rüya
# 26Sanşiro
# 26MobyDick
# 26KırmızıKitap
# 26Ankara
# 26İnsanlığınYıldızınınParladığıAnlar-OnDörtTarihselMinyatür
# 26DününDünyası
# 26YüzüklerinEfendisi-III-KralınDönüşü
# 26Victoria
# 26Ah'larAğacı
# 26SınırınYasaları
# 26Divan
# 26AşkaDairNesirler
# 26BütünŞiirleri-CahitZarifoğlu
# 26BatıdaYeniBirŞeyYok
# 26MatmazelNoralya'nınKoltuğu
# 26Yalnızlar
# 26ÖlümDikenÜstünde
# 26ŞahaneHatalar3-BiraveKadın
# 26ÇiçeklerSusayınca
# 26Cinnet
# 26BuKöşedekiAdam
# 26SenAydınlatırsınGeceyi
# 26Aforizmalar
# 26HayalAğacımİğde
# 26BirKuştanÖbürüne:HayatveYazmakÜzerineTavsiyeler
# 26DorianGrey'inPortresi
# 26Kierkegaard'danHayatDersleri
# 26OradaMerhametVarmış
# 26Çocuk
# 26YedinciHaç
# 26GünOlurAsraBedel
# 26Kısas
# 27TroçkiCilt1:Ekim'eDoğru(1879-1917)
# 27PapadopulosApartmanı
# 27UzunBirYalnızlığınTarihçesi
# 27İnsanKendindeOlmayanıArar
# 27BilinmeyenBirKadınınMektubu
# 27Eleştirirken-ModernTürkçeEdebiyatÜzerineYazılar
# 27Ardavirafname
# 27BenBirDevrimciyim
# 27OÖyleOlmadı
# 2701Adana-80'liYıllardaAdana
# 27HayatıHerGünYeniBaştanKeşfetmek
# 27UluHanAtaBitiği-TürklerinEnEskiDestanı
# 27PirSultanAbdal
# 27EliaİleYolculuk
# 27RüzgaraBırakılanDilekler
# 27UçArtık
# 27KüçükÖfkeliGezegeneYolculuk
# 27BaşıbozukGünceler
# 27OtDergisi-Mayıs2022
# 27BörüDörtleme
# 27JaneCaseyPolisiyeSeti2-3KitapTakım
# 27DanteAlighieri:Gururlu-Hırslı-Ukala-KaranlıkBüyükHikayeler
# 27Kritimu-Girit'imBenim
# 27KürklerÜlkesi-OlağanüstüYolculuklar33
# 27OtostopçununGalaksiRehberi-RadyoTiyatrosu
# 27Romanperverİktisatçı
# 27Buluşmalar-YazarlarRessamlar
# 27PenguenlerAdası
# 27KıyametTreni
# 27Muhabbetnağme
# 27SilahAdası
# 27CennetÇürüdü
# 27ÖlüRuhlarArşivi
# 27SizBirAlçaksınız!
# 27JaneEyre
# 27YaşamakveYazmak-FrankfurtDersleri
# 28NarÇiçekleri
# 28OrhanVeli-BütünŞiirleri
# 28ÇocukEdebiyatı-AraştırmaİncelemeEleştiri
# 28ArsenLupen-KibarHırsız
# 28Lise100TemelEserSeti-Kutulu-40KitapTakım
# 28ArsenLüpen-Oyukİğne
# 28BirÇocuğunİstanbulHatıraları1901-1913
# 28MakarınRüyası
# 28CezaKanunu353.Madde
# 28Köle-Aşk
# 28DostoyevskiSeti-4KitapTakım
# 28DeccalinAskerleri
# 28KoyunBaba
# 28TaşradaBirAy
# 28KalptenGelenArmağan
# 28Dünya'nınUcundakiFener-ModernKlasikler173
# 28CanVerenPervaneler-3
# 28Rosemary'ninBebeği
# 28DüşünenTürkçe
# 28SözcüklerinBilinci
# 28KülKelebek
# 28MaviListeDenglerinİlkVakası
# 28SolgunAteş
# 28AnılarınlaBarışırsanÖzgürleşirsin
# 28SamuelBeckett:VarlığaEşlikEdenKahramanlar-AnlatıDesenleri2
# 28YangınGecesi
# 28KorkununKrallığı
# 28AşkAptallığı
# 28GözyaşlarıveAzizler
# 28Aslanınİni
# 28KırmızıKöşk'ünEsrarı
# 28Gençlik
# 28GörenGözler
# 28Dünyasızlar
# 28O
# 28Yaralasar3
# 29Tirza
# 29KarKörlüğü
# 29ÇocuklariçinYazmak
# 29İlahiKomedya-WilliamBlake'inResimleriyle
# 29TolstoyGandhiMektuplaşmaları
# 29Psikopat5-ÖzelBaskı
# 29Derviş
# 29BeniSessizdeSevebilirmisin?
# 29AnlamaktanYoruldum
# 29ŞairEvlenmesi-TürkEdebiyatıKlasikleri5
# 29RogerAckroydCinayeti
# 29Arzu
# 29Unutursun
# 29Decameron
# 29BayYüzdeBeş-DünyanınEnZenginAdamıKalustGülbenkyan'ınFarklıHayatları
# 29ÜçeKadarSay
# 29BirSahafÖldüDiyeler-EtemÇoşkunKitabı
# 29İkinciHayat:Kaçmak-Kovulmak-DönmekÜzerineDenemeler
# 29Paris'teSonOsmanlılar-MedihaSultanveDamatFerit
# 29DeğişenBirŞeyYok
# 29SonunFenomenolojisi
# 29Keşke'sizBirKadın
# 29Luviler:Anadolu'nunIşıkİnsanları
# 29MüminlerinEmiriHz.Ali
# 29KolımaÖyküleri
# 29İsimŞehirHayvan
# 29PanzerlerÜstümüzeKalkar-BütünŞiirleri
# 29HiçliğinMutluSessizliği
# 29GugukKuşu
# 29ZamanımızınBirKahramanı
# 29KapıBirdenVuruldu
# 29KarartmaGeceleri-BütünEserleri
# 29YaşamınınSonYıllarındaGoetheileKonuşmalar-HasanAliYücelKlasikleri
# 29PeterCamenzind
# 29KaranlıkBüyükHikayeler
# 29YaşlanmayaVaktimYok
# 30DeğişenBirŞeyYok
# 30Troya'daÖlümVardı
# 30Fotokopiler
# 30LodoslarKenti
# 30MekruhKadınlarMezarlığı
# 30MerhabaAnadolu
# 30Leviathan
# 30TurgutReis
# 30EmirBey'inKızları
# 30Kimlik
# 30KırmızıPapağan
# 30Ağaçkakan
# 30Şeyler
# 30ŞarkıOkumaKitabı
# 30BinbirGeceMasalları2/2
# 30ÇatalDil
# 30Gölge
# 30BirÇöküşünÖyküsü
# 30ZamanımızınBirKahramanı
# 30YürektekiHayvan
# 30BirRüyaGibiHatırlıyorumSeni-YaşamımdanAnılar2
# 30İşaretÇocukları
# 30Deccal'inHatırı
# 30SeyrekYağmur
# 30BalkonSefası
# 30AyHan'ım
# 30HenriettaLacks'inÖlümsüzYaşamı
# 30Varoluş
# 30Ayrılış-BirGökçeadaHikayesi
# 30EveGidenUzunYol:SerefxaneBedlisi-CagıYasamıveOlumsuzKisiligi
# 30EvdaleZeynike'ninHayatındanBirGün
# 30BirLevanteninBeyoğluAnıları
# 30BeyazDiş
# 30GüvercinlerGittiğinde
# 30Vartanuş'unAli'si
# 30ÖrümcekAğı
# 31BeyazZambaklarÜlkesinde
# 31ÇanlarKimseİçinÇalmıyor
# 31KeltŞafağı
# 31GerçekHayat
# 31ScarletveIvyKayıpİkiz
# 31Rimbaud
# 31BozkırdaAltmışaltı
# 31Tol
# 31Merhamet
# 31KalabalıktaYüzler
# 31YüreğimeYolculuk
# 31SiyahKelebek2-Capella
# 31EskimoMasalları
# 31SevgiveAdalet
# 31Unorthodox
# 31CravenMalikanesi
# 31AtSancısı
# 31KaraçamOrmanı'nda
# 31TanrıÇocuğuKorusun
# 31SönmüşHayaller2-TaşralıBirBüyükAdamParis'te
# 31JakobVonGunten
# 31Truva-İlyadaveOdysseiaHikayeleri
# 31HitlerKitabı
# 31Felsefe'ninTürkçesi
# 31SinekIsırıklarınınMüellifi
# 31DonKişot'tanBugüneRoman
# 31AptallarErkenÖlür
# 31ThereseRaquin
# 31BirSürgün
# 31AynadaAşkVardı
# 31BirYerde
# 31ÇılgınlığınÖtesi
# 31GeceYarısıŞarkıları
# 31Kule-KaraKuleSerisi7.Kitap
# 31ÇatıkatıAşıkları
# 31HalkHikayelerininMotifYapısı
# 32BöyleGelmişBöyleGitmez2-YokuşunBaşı
# 32BozkırdakiKıvılcımEnstitülüler
# 32OncaYoksullukVarken
# 32KurutulmuşFelsefeBahçesi
# 32YıldızlarıHesaplamak
# 32JimCarreyveDanaVachonAnılarveYanılsamalar
# 32ŞehzadeyeRüya
# 32TelaşBandosu
# 32ÇatlakKrallık
# 32SpiritüalizminTarihi-Cilt2
# 32DünGeceNeredeÖldün?
# 32SessizlikTarihindenGünler
# 32LadyL.
# 32Kovalamaca
# 32Ötekiİstanbul-ÖlüdenDoğan
# 32Pippin4'ünKısaSürenSaltanatı
# 32DenizKızıAğladığında-HediyeliÖzelKutu
# 32KramponluCeset-ÖzelBaskı
# 32AğzındaKaranfilTaşıyanGençAdam
# 32ElYapımıRuhlar
# 32İskandil-Günlükler1968-1969
# 32AlMidilli
# 32MaraziBirKemikMerakı-CadfaelBirader1
# 32Köken
# 32MezardaİlkGeceYaşanacaklar-BirKürekçininHikayesi
# 32ErikAğacı
# 32Birdenbire
# 32Kıskanmak
# 32SherlockHolmes-BütünHikayelerTekCiltÖzelBasım
# 32KaraDüşenAyIşığı
# 32Maldoror'unŞarkıları
# 32Nefes-BirKarar
# 32Budala
# 32ÖlümGeceGelir
# 32ÖlümveBahar
# 32BirAşağılamaAracıOlarakÇöp
# 33KaraDüşenAyIşığı
# 33Budala
# 33ŞehzadeyeRüya
# 33TelaşBandosu
# 33ÇatlakKrallık
# 33EvdaleZeynike'ninHayatındanBirGün
# 33DenizKızıAğladığında-HediyeliÖzelKutu
# 33KramponluCeset-ÖzelBaskı
# 33AlMidilli
# 33MaraziBirKemikMerakı-CadfaelBirader1
# 33SessizlikTarihindenGünler
# 33LadyL.
# 33DünGeceNeredeÖldün?
# 33EveGidenUzunYol:SerefxaneBedlisi-CagıYasamıveOlumsuzKisiligi
# 33YıldızlarıHesaplamak
# 3372.Koğuş
# 33HayatİncitirHerkesi
# 33YaBirGünKavanozKapaklarıBiterse?
# 33SolgunKaranfil
# 33Lunapark-GereonRath'ınAltıncıVakası
# 33BinbirGeceMasalları2/1
# 33EvrakKürek-SektördenArkadaşlaraGiriş101
# 33Serenad
# 33AritmiKoridoru-EverestDeneme
# 33HayvanMezarlığı-GeceninPençesi
# 33Riga'nınKöpekleri-KurtWallanderSerisi2
# 33Cehennem
# 33BuzAltındaYanardağ
# 33Önsezi
# 33TemizlikçiKadınlarİçinElKitabı
# 33KibritÇöpüMezarlığı-ÖlümeFısıldayanAdam2
# 33GüneşteUyumak
# 33Eflal
# 33YolcuveBurjuva
# 3333
# 33RedWhite&RoyalBlue
# 34Kadınlar
# 34BütünŞiirleri-SabahattinAli
# 34AltıncıIrk
# 34IslakBalık-GereonRath'ınİlkVakası
# 34SeksveÖfke
# 34BirGöçmenKuştuO
# 34SonŞeylerÜlkesinde
# 34BirKaçırılmaÖyküsü
# 34RomantikYalanveRomansalHakikat
# 34Dersaadet'teDans
# 34AğustostaTatil
# 34HiçİçinMetinler
# 34EvreninHikayesi-Tanrı'nınAğzından
# 34YüzüklerinEfendisi-II-İkiKule
# 34BuzSarayı
# 34VedaDivanıTopluŞiirler1966-2016
# 34BirHaremağasınınHatıraları
# 34TürkiyeSenKimsin?UçmakderYazıları1
# 34KartalYuvasıAlamut
# 34ÖldürenSırlar
# 34BizEvleniyoruz
# 34Wittgenstein'inMetresi
# 34YarımKalanYürüyüş
# 34ÇocukluğumGençliğimSiyasiveEdebiHatıralarım
# 34HükümGecesi
# 34HaneneAyDoğacak
# 34AlainRobbeGrilletveYeniRoman
# 34KanlıTopraklar
# 34Veda-EsirŞehirdeBirKonak
# 34KaçakçıŞahan
# 34MalcolmX
# 34HayatTeselliBulmaktır
# 34EfkarTepesi
# 34Soğuk-BirSoyutlama
# 34KulaktakiMeşale
# 34SüleymanDemirel
# 35AvaHava
# 35BirEdebiMuhitOlarakAnkara1923-1980
# 35Tarlakuşu
# 35GençBirDoktorunNotDefteri
# 35KendinleSavaşmaSanatı
# 35TatlıRüyalar
# 35YıldızlarıYenidenYakmanınVaktiGeldi
# 35KürtÇoban
# 35VatansızAdam
# 35SabihaSertel:HayatıveEntelektüelMirası
# 35AtlantikSavaşı:Greyhound
# 35ÇocukEdebiyatıOkumaları
# 35BayPerşembe
# 35GüvercinlerHavalanırken
# 35Şahname-3
# 35BenDahaYaşamadım
# 35VeKış
# 35FareKapanı
# 35SakalsızBirOğlanınTragedyası
# 35TamOSırada
# 35Kürar
# 35Eylül
# 35YağveMermer
# 35DurgunDon-4CiltTakım
# 35ArtvinArtvin
# 35BabamınVasiyeti
# 35Tepetaklak
# 35TanrılarınAlacakaranlığı
# 35BütünŞiirleri
# 35PuşkinTepeleri
# 35YüzyılınSuçlusuBlaze
# 35SularTanıktırAşkımıza
# 35KaybedilmişBirBahistir
# 35YediKrallıkŞövalyesi
# 35ClaudeLevi-Strauss:LabarutuvardaBirYaşam
# 35DarZamanlar-3KitapBirAradaTekCilt
# 36ÖteDünyalar
# 36MahkumlarınŞafağı:Özyaşamöyküsü1921-1946
# 36YüreğiYüzündenGüzel:TarıkAkan
# 36Marje-MaçaKadın
# 36DenizDuası
# 36Kavgam
# 36GençYazarlarİçinHikayeAnlatıcılığıKılavuzu
# 36KaranlıkYüz-BirKuzeyPolisiyesi
# 36MaviDantel
# 36UzakNoktalaraDoğru
# 36KırdığımızOyuncaklar
# 36AteşböceğiYolu
# 36HavuzluYazlık
# 36EnginGeçtanEdebiyatSeti5KitapTakım-Hediyeli
# 36OSırada
# 36İmzalı-TebeşirTozu
# 36Amasanga-BirBaşkaAdıylaAmazon
# 36Metinler
# 36BüyülüBeyoğlu
# 36OGemiGeleneKadarBenUçmayıÖğrendim
# 36Alemdağ'daVarBirYılan
# 36YıkılmışKadın
# 36HafızaPolisi
# 3619Dakika
# 36Kalıntı-1
# 36EskiDünyanınYangını
# 36MaviTüy-GönülsüzBirMesihinSerüvenleri
# 36Cudi-Nuh'unGemisininİzinde
# 36YalnızlığınOnBirHali
# 36DağlarKızıGülenayÖğretmen
# 36KelebekileKeman
# 36NagalarınSırrıShivaÜçlemesi2
# 36CogitoSayı99-Spinoza:TazeBirNefes
# 36İçindeBirSen1:Engerek-Poster-Defter-Ayraç-PolaroidFotoğrafHediyeli
# 36BirİdamMahkumununSonGünü
# 36YabanaDoğru
# 37AklındanBirSayıTut
# 37TütüncüÇırağı
# 37HerTemasİzBırakır
# 37YeşilinKızıAnneSeti-5KitapTakım-Kutulu-ÖzelÇanta-Poster-KartpostalveRozetHediyeli
# 37SenGittinGideli
# 37BenimAdımNeymar
# 37GizliAjans
# 37SherlockHolmes-BütünHikayeler1
# 37YalancılarveYabancılar
# 37BirİngilizAfyonTiryakisininİtirafları-HasanAliYücelKlasikleri
# 37Karantina-ÜçüncüPerde-MahşerinDörtAtlısınınHikayesi
# 37OZamanGerçeğiNasılÖğreneceğiz?
# 37EkberŞah
# 37AsilAşk
# 37Madenci
# 37KirazAğacı
# 37AşkileAnıSeyretmek:GönülSadasındanAkisler-2
# 37YediKartalEfsanesi1.Kitap-ZülfikarınHükmü
# 37YeşilIşın-OlağanüstüYolculuklar26
# 37KurguSanatı-KısaÖyküveRomanSanatıİçinKlasikBirRehber
# 37MelihCevdetAnday:Mikado'nunÇöpleri-EverestAçıkhava3
# 37FazladanBirCeset-CadfaelBirader2
# 37BirKadınPolitikacınınAnıları
# 37BinLotlukCeset-ÖzelBaskı
# 37KaraBuz
# 37ArsenLüpen-HerlockSholme'eKarşı
# 37YokluğumdanAklımdaKalanlar
# 37Kılavuz
# 37GülMevsimidir
# 37D.H.Lawrence
# 37BalıkçılGözü
# 37TepedekiEv
# 37DersimizCinayet
# 37BeşinciDağ
# 37TonioKröger
# 37BerenileLuthien
# 38DışGüzellikYasaklansınRuhGüzelliğineGeçelim
# hata tespit
# hata tespit
# 38İkiAşina
# 38Yalnızlığın17Türü
# 38TürkRomanındaÇanakkaleMuharebeleri
# 38BirYazarınGüncesi
# 38AşırıGürültülüveİnanılmazYakın
# 38Gizliajans
# 38Marx-21-2
# 38YirmiüçOn
# 38BirFilizVardı
# 38SoyluSınıfınSonbaharı
# 38DindarBirDoktorHanım
# 38GranitveGökkuşağı
# 38ÜcretArtışıTalebindeBulunmakİçinServisŞefineYanaşmaSanatıveBiçimi
# 38BirBaşkaŞehir
# 38GeceYarısıİşgalAltındaİstanbul
# 38EtilerKoğuşu2
# 38TanrılarÜlkesindeAşk
# 38YanılsamalarKenti
# 38Nereye?
# 38Panorama-BütünEserleri-18
# 38Arkadaş
# 38BirNoelEzgisi
# 38BaşkasınınKarısı
# 38GüneşÇocuğu
# 38Köylüler
# 38İnsancıklar
# 38MartinEden
# 38AlınTeri
# 38HalkAvcısı
# 38Karacaoğlan-BütünŞiirleri
# 38PirSultanAbdal
# 38BüyücüveCamKüre-KaraKuleSerisi4.Kitap
# 38EdebiyatÜstüneYazılar
# 39Sefiller-2KitapTakımKutulu
# 39Naviga-Mayıs2022
# 39EminÇölaşan'aMektuplarımveSonrası
# 39BaşkaldıranAtlarınRessamı
# 39YeşilYol
# 39CehennemGünlüğü
# 39Türkİnsanı
# 39Soyka
# 39NetoçkaNezvanova
# 39Baragan'ınDikenleri
# 39Pulp
# 39YılmazGüney'leYasaklıYılları
# 39Postane
# 39BarışAdlıÇocuk
# 39Bakmak
# 39DeğişenKahramanımız
# 39ÜçüncüTekilŞahıs
# 39Türkiye'deBeşSene
# 39Gündönümü
# 39SarıYazma
# 39YokuşYukarı
# 39BurdaÖrgü-Mart2022
# 39MarathonBirUzunKoşu
# 39BenBuradayım...
# 39IV.Murad-1
# 39EbabilKuşları
# 39DodorgaGünlükleri
# 39BirŞarkıyıDinlerken
# 39EğretiErkekler
# 39ElKızı
# 39EskiŞiirinRüzgarıyle
# 39Sözcükler-TopluŞiirler
# 39ÇokSesliBirÖlüm
# 39NeyinNesisinSen
# 39Güven(Cilt2)
# 39ToplumsalKurgularveCinsiyetçilik
# 40TorunumaYunanMitleri
# 40CogitoSayı58-Feminizm
# 40OsmanlıHaremindeÜçHasekiSultanı
# 40KanatlarınÇağrısı
# 40Eylül
# 40CüneydOrhonAnlatıyor:RadyoGünlerim
# 40HerŞeyAydınlandı
# 40DerinTarih-Mayıs2022
# 40SuskununGölgesinde
# 40KocataşYalısıAnılarım
# 40Bırakmak
# 40ÖlünceyeKadarSeninim
# 40ŞarabınŞiiri&EsrarınŞiiri
# 40ŞiirveCinayet
# 40YediNumaralıRadyo
# 40HükümdarlarHükümdarıSargon
# 40İkna
# 40Buradayız
# 40KülOlmuşGölgeler
# 40GülfimAbla
# 40Paris
# 40YunusEmre
# 40ZeynaSavaşTanrıçası4-Sfenks'inTuzağıAvcıKadınveSfenks
# 40SahandaYumurta
# 40MaskeveGölge
# 40KarlMarx
# 40YeniGülzar-ıHaseneyn
# 40KayıpGül
# 40MahkemeKitap
# 40Medici
# 40KıyametGünüUstası
# 40Theogonia'ninEsasları
# 40MazgallarınAltında
# 40SaatinGizliYüreği
# 40HayretPerdesiniTemaşa
# 40OrgelKontu'nunBalosu
# 41Biz
# 41İnsanKendineDeİyiGelir
# 41HawaiiÖyküleri
# 41MakaloaHasırıÜzerinde
# 41KanSanatı-BirSherlockHolmesMacerası
# 41ÇocukNazi
# 41KehribarZamanındaAşk
# 41SevinçKuşları3-SonŞura
# 41SherlockHolmes-BütünHikayeler-5KitapTakım
# 41FilvariUsta-MuğlalıMimarMihailKostantinoğlu
# 41YeniTürkiyeBilimveTeknolojiÖzelSayısı5CiltTakım-Sayı8889909192
# 41Meryem'inTanıklığı
# 41CihanFatihiOğuzKağan
# 41GagavuzEdebiyatı
# 41AhMercimeğim
# 41ŞiirinOİnceKülleriniToplayanlar
# 41BabildeÖlümİstanbuldaAşk-MidiBoy
# 41Casus
# 41HevesiKirpiğinde
# 41ÖyküMenzilleri1
# 41HayaliMektuplar
# 41AslanAskerŞvayk
# 41DelicesineMutlu
# 41SensizAsla!
# 41GençWertherinAcıları
# 41BirKadınınMektubu
# 41Dönüşüm
# 41AnnaveFransızÖpücüğü
# 41MüebbetTürküsü
# 41Ezilenler
# 41KazakEdebiyatı
# 41ZamanınManzarası
# 41ÖğretmenOlmadanÖnceÖğrenciydim
# 41HoşBuldukLondra
# 41MinareGölgesi
# 41Dalga
# 42MiladınBaşlangıcıNasıralıİsa
# 42DostMektupları
# 42HerŞeyAyartabilirBeni
# 42OğlakDönencesi
# 42DedemBirYanıkTürkü
# 42İvrizKöyEnstitüsüAnılarım
# 42CingözRecai-ZeyrekCinayeti
# 42CogitoSayı79-CogitoSöyleşileri
# 42BirHavaTaarruzuSırasındaBarışÜzerineDüşünceler
# 42YaşarKemalyadaDionysosunDönüşü
# 42VampirGünlükleri-Kurtuluş-Maskesiz-Vol3
# 42Musa'nınSırrı-AnaTanrıça'nınYolunda
# 42WapshotKayıtları
# 42SönmüşHayaller1-İkiŞair
# 42HemingwayHırsızı
# 42YaşamSuyu
# 42GizliÇekmece
# 42MuhteşemGatsby
# 42ÖlümDalgaları
# 42HayHikayeler
# 42AçıkMektuplar
# 42TerkEtmeBeni
# 42Köroğlu
# 42Diriliş
# 42SatrançOynayanDerviş
# 42İşlenmemişSuç
# 42NasipseAdayız
# 42Hayal'et
# 42Psiko-Büyü
# 424Hane1Teslim
# 42ÇocukluğuOlmayanAdamlar
# 42IşıklaKaranlıkArasında
# 42ÖtekiPusula-SanatveEdebiyatÜzerineDenemeler4
# 42HasarAyini
# 42HayatKısaMutluOlmayıİhmalEtme
# 42BuzdaYürüyüş-MünihParis
# 43KanınGünlükleri-BuzAteşi
# 43TürkSeriKatiller
# 43Töre
# 43OyunİçindeOyun
# 43PrusyalıSubay
# 43HiçDeğilseBugün
# 43KaygılarımızınKışı
# 43JaponŞiiri(Haiku)veNooTiyatrosu
# 43AzizNesin'liAnılar
# 43TaygaSendromu
# 43PadişahınKaftanı
# 43OnİkiCaesar'ınYaşamı
# 43AyrılıkOyunları
# 43KalbinSırları
# 43KaramazovKardeşler
# 43Psikoterapist
# 43SeniYarınÖzleyeceğim
# 43SoğukDeri
# 43KendiIşığındaYananAdam
# 43YeraltındanNotlar
# 43Cogito91-NeoliberalizmdeÖznellik
# 43YakıcıSır
# 43UzaklarınSaldırısı
# 43RadikalKitaplar
# 43DerindekiHesaplaşma
# 43GülenPolis
# 43BüyükSoytarı
# 43OğlununKalemindenAhmetMidhatEfendiveDönemi
# 43YorgunSevda
# 43Efsunkar
# 43HeybeliadaCinayetleri
# 43Sırdeli
# 43AntonÇehovBütünEserleri5-1886
# 43YağmurKral
# 43MeleklerinUğramadığıYer-İletişimKlasikleri
# 43AşkınLHali5.Cilt2018-2020
# 44SonPatron
# 44BaraganınDikenleri
# 44ZaptiyeAhmet-CumhuriyetDevrindeBirOsmanlıAkıncısı
# 44NezaketDili:BirHemşireninÖyküsü
# 44TolstoyMakalelerVeMektuplar
# 44MaviBirYaşam-BirSoluktaKlasikler
# 44KüldenHece-MeftunSerisi1
# 44ŞairveMatematikçiÖmerHayyam
# 44KızılÖlümünMaskesi
# 44Korkuyorum
# 44KendineAitBirOda
# 44SavaşveEdebiyat-EdebiyatınTanıklığındaSavaşlarveSonrası
# 44BenceKatilÖldürdü-BirHerculedePotassePolisiyesi
# 44DünyanınHikayeEdilişi-HarikalarKitabı
# 44TanrılarSusamışlardı
# 44LatifeTekin'inRomancılığı
# 44Sözleşme-1
# 44EnKötüŞeyÖldürmeyenAcılardır
# 44HalilCibran'danYaşamınKüçükKitabı
# 44EdebiyatsızEdebiyat-Eleştiri
# 44MimarSinan
# 44BirhanKeskinSeti5KitapTakım
# 44İlkMüslüman
# 44NocillaRüyası
# 44KaktüslerdeÇiçekAçar
# 44İçimdeki
# 44Handan
# 44MürekkebeBoyananSardunya-2
# 44HerŞeySuİleBaşladı
# 44KötüBirYılınGüncesi
# 44Fil
# 44Metro2035
# 44Sarsıntı
# 44YeşilinKızıAnne-RüzgarlıKavaklar-BezCiltli
# 44AyDüğümü
# 44Öteki
# 45GölSaatleri-ÖlümsüzKlasikler
# 45LeukoİleSöyleşiler
# 45Günlükler
# 45HalkŞiirimizinGücü
# 45MendilAltında
# 45BirKayıpDenizci
# 45CumayadaPasifikArafı
# 45Theo'yaMektuplar
# 45GünlerinGetirdiği-SözdenSöze
# 45Kısas-ıEnbiya
# 45ÇiçeklerinDüğünü
# 45HavaParası
# 45İzmirHikayeleri
# 45KırmızıKaranfil
# 45ÇocuklarveBüyükleri
# 45Kıskaç
# 45SevgiMektupları
# 45Tamgalar
# 45İblisBurger
# 45KafkasHalkDestanları
# 45KaranlıkOkyanus-Serdengeçti
# 45VahşiFabl-BütünKurmacaları
# 45CanVerenPervaneler-5
# 45İçimdekiYabancı
# 45Sene84
# 45KaranlığınŞehri
# 45BatıdakiDoğu
# 45NeGeçmişTükendiNeYarınlar
# 45ViskiRing
# 45StefanZweig'inVedaMektubu
# 45YeşilinKızıAnne5-RüyaEvi
# 45SavaştaYavuzŞiirdeSelim-YavuzSultanSelimŞiirleri
# 45KimsesizlerMatemi
# 45İntiharveBilimkurgu
# 45SenBeyazsın
# 45ÖyküGazetesiSayı:23
# 4622Kadın22Öykü
# 46EpikDamar-990SonrasıTürkŞiiriveEpikReferansları
# 46TehlikeliDuzaklar
# 46ErzincanlıDivaneAzizBaba
# 46VeÇeliğeSuVerildi
# 46İlkÖyküler-RasimÖzdenören
# 46AtlarıdaVururlar
# 46DişiKurdunRüyaları
# 46İyiEşler-BezCiltli
# 46ŞairPortreleri
# 46SurKentiHikayeleri
# 46UcundaÖlümVar
# 46CanVerenPervaneler-1
# 46Delilah'ınÜçRengi
# 46ZorluBirKış
# 46Eumeswil
# 46YeşilinKızıAnne7-GökkuşağıVadisi-BezCiltli
# 46HerŞeyinBittiğiYerden
# 46DörtMevsimGazozu
# 46GriAdam
# 46BirŞansDaha
# 46Hachiko
# 46100TürkBüyüğüSeti-5CiltTakım
# 46KısaBirCehennemZiyareti
# 46TropikGüncesi
# 46YeşilinKızıAnne-BezCiltli
# 46Chancellor-OlağanüstüYolculuklar25
# 461984
# 46YalancıBirBoşluk
# 46AltınZincir:SonSaatler1.Kitap-GölgeAvcılarıDünyasınınYeniSerisi
# 46İsfahan'ınGözyaşları
# 46YokÇünküTelafisi
# 46Notos91-Mayıs/Haziran2022
# 46KahininMektupları
# 46MaxiBulmacaSudoku-Mayıs/Haziran/Temmuz2022
# 46EdgarAllanPoe-BütünÖyküleri-2KitapTakım
# 47TaşraKızınınDeliceleri
# 47BaşıboşŞiirlerinYalnızlığı
# 47FranchiseDavası
# 47DoğuBatıDergisiSayı97-AkılTutulmasıÇağı2
# 47SiyahKoku
# 47Kelebek
# 47DemirYaylıDukak
# 47ÖncekiGece
# 47UzayGezginiTuf
# 47Katilinİçgüdüsü-DoğuştanYetenekliler
# 47YüzünüSıyırKaranlığından
# 47ŞairinÖlümü
# 47Böcü
# 47BirElmanınİkiYarısı
# 47SessizlikveGürültü
# 47Annelik
# 47Absentium:YazarınDönüşü
# 47BüyülüBirYaşamİçinMistikMasallar-HiçDuyulmamış11VedikHikaye
# 47SahalinAdası
# 47TürkEdebiyatındaYunanAntikitesi(1860-1908)
# 47KimseGerçekDeğil
# 47BöğürtlenKışı
# 47YazarOlabilirmiyim?
# 47SodomveGomore
# 47G.H.yeGöreÇile
# 47HayatındakiTümKışlarıUnutanAdam
# 47ArsenLüpen:HerlockSholmes'eKarşı
# 47LordlarveVarisler-HepimizGökyüzüOlmakİstedik(ÖzelİmzalıKutulu)
# 47Seçilmişler
# 47HayalGücünüEğitmek
# 47HayatıEmenKaranlık
# 47MetalFırtına8-HakikatMuhafızları
# 47KirpiMesafesi
# 47KöprülüMehmedPaşa
# 47Goldstein:GereonRath'ınÜçüncüVakası
# 47SümbülKokuluParfüm
# 48MucizeyiTaşımak:EğlenceliBirHamilelikHikayesi
# 48HikayeAnlatıcısı
# 48UyandırılmışToprakCilt1
# 48Dünya'nınMerkezineYolculuk
# 48NasreddinHocave1616Fıkrası
# 48KaptanKöşkündePanik
# 48OlmayanKuşlarAnsiklopedisi
# 48YerüstüHazinelerimiz
# 48MaxiBulmaca-Mayıs/Haziran/Temmuz2022
# 48BanaDokunma
# 48YansıtmaDergisiSayı28
# 48PeyamiSafa'nınİnsanları
# 48KelimelerinKalbi
# 48DünyadanAşağı
# 48CumhuriyetDönemiTürkEdebiyatı-YeniTürkEdebiyatı2
# 48SözcüklerdirBütünDerdim
# 48EnayiBirAşk
# 48SavaşSanatı
# 48KışGüneşi
# 48CamArılar
# 48Ses
# 48KüçükSözler3
# 48TürlerinTükenişi
# 48SultanİkinciAbdülhamidHan2-UzaklarıGörebilenHükümdar
# 48BalkondakiAdam-MartinBleckSerisi3
# 48GeceyeUyananlar
# 48Kıyısız-ŞiddetinÇocukları4
# 48TürkHalkBilmeceleri
# 48Ra-Gözcüler
# 48Kıyısızlar
# 48YüzündenYollarÇıkardım
# 48UmutAslaTükenmez
# 48MuhteşemGatsby
# 48Rumeli'denYemen'e-BirOsmanlıBulgarHekimininHatıraları
# 48YaşanmışŞiirler
# 48BirOkurunNotları
# 49BirÇocukAskerinAnıları
# 49MutlulukKendiKendineYetenlerindir
# 49FelatunBeyileRakımEfendi
# 49AntonÇehovBütünEserleri4-1885
# 49Aile
# 49YeşilinKızıAnneSeti-5KitapTakım
# 49AteşveKılıç
# 49Esir:GerçekBirEsaretHikayesi
# 49KüçükKibritçiKızınÖlümü
# 49HuckleberryFinn'inMaceraları
# 49SadeceŞeyma
# 49İmzalı-BenTekSizHepiniz
# 49SavaşÖyküleri
# 49Köseler'denHollanda'yaYaşamSavaşım
# 49BirZamanlarHayatBizimdi
# 49BenAntoninArtaud
# 49Anayurt
# 49GiysilerNeAnlatır?
# 49AramızdaBirBahçeYakınlığı
# 49SiyahveMavi-BirDedektifJohnRebusPolisiyesi8
# 49AsilDuygular
# 49KöylülerKodamanlarveBombalar
# 493391Kilometre
# 49Şıpsevdi
# 49Gırgır
# 49BirTÖSVardı
# 49TürkişDekameron
# 49SönmüşHayaller3-BirYaratıcınınÇektikleri
# 49ThomasBernhard'ınDerKultererAdlıYapıtındaHeterotopya
# 49BirHakimeYakışanıYazdım
# 49KurdularM'olaÇadırlarıÇemen'e
# 49GözlerindekiSır
# 49ZilhaGünü
# 49FranzKafkaSeti-3KitapTakım
# 49AhMinelAşk
# 49MaceraveBilimKurguKitaplığıSet1-2KitapTakım
# 50SüreyyaPaşa
# 50YarınBizimdirYoldaşlar
# 50IşığınTacı-AteştenKorkanEjderhaSerisi1
# 50SonBlues,BirGünOkunacakOlan-SeçmeŞiirler
# 50BörüPençesi-YadaTaşıEfsanesi3
# 50GalibaBendeEkonomistim
# 50Dulhane
# 50Dilaltı
# 50KocaAdam
# 50TutuklununGünlüğü
# 50SorumluBulutlar
# 50BriçMasasındaCinayet
# 50EjderhanınGözleri
# 50Einstein-YaşamıveEvreni
# 50BeyazAt
# 50Galata
# 50Selanik,KahpeSelanik
# 50MasumiyetveTecrübeŞarkıları-HasanAliYücelKlasikleri
# 50KardeşiminMezarı
# 50Jar
# 50OnÜçSıfırSıfır
# 50SınırlaraHayır-RosaLuxemburg
# 50TekinsizliğinPsikolojisiÜzerine-TekinsizlikÜzerine
# 50GöğünMavisi
# 50EmileyadaEğitimÜzerine
# 50Eşkal-iZaman
# 50UçmaTaklidi
# 50AkşamaYemekYokYersenÖyküVar
# 50DoğduğumEv
# 50Muhit-Mayıs2022
# 501473
# 50MarienbadAğıdı
# 50CengizHan
# 50SuGibi
# 50BeyazGüllerAçarken
# 50DişiAslanınİtirafı
# Comment number: 1789

# %%
with xlsxwriter.Workbook('test.xlsx') as workbook:  #generate file test.xlsx
    worksheet = workbook.add_worksheet()
    for name, comment in enumerate(dataset):
        worksheet.write_row(name, 0, comment)
